# %% [markdown]
# Image source: https://www.kaggle.com/datasets/oddrationale/mnist-in-csv

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %run .././combinations_of_permutations.ipynb

# %%
image_vectors = []
with open('mnist_train_first32.csv', mode ='r') as file:    
    csvFile = csv.reader(file)
    next(csvFile)
    for line in csvFile:
        image_vectors.append(vector(QQ,[int(entry)/255 for entry in line]))

# %%
firstPic = np.array(image_vectors[0][1:]).reshape((28,28))
secondPic = np.array(image_vectors[1][1:]).reshape((28,28))
imgplot = plt.imshow(secondPic)

# %%
permutation_set = genPermutationsBetween(2,6)
print(len(permutation_set))
# Out:
# 872

# %%
fuzzy_matrices = [combination_of_permutations([1],[sigma]).genFuzzyMatrix(28)/factorial(28) for sigma in permutation_set]

# %%
flats = [vector(QQ,m.list()) for m in fuzzy_matrices]

# %%
M = matrix(QQ,flats)
sol = M.transpose().pseudoinverse() * vector(QQ,secondPic.flatten())
rho = combination_of_permutations(sol,permutation_set)
final_image_blown = rho.genFuzzyMatrix(28)

# %%
for i in range(len(sol)):
    print(float(sol[i]))
# Out:
# 14.90739493988543
# 40.20726109201886
# 79.90094425655147
# -20.187151079154535
# -37.352700767568784
# -7.278165690643251
# -31.28678654198
# 98.87584387065154
# -153.97906041937168
# -92.66107930328357
# 302.24805359026783
# 184.16939996818618
# 80.10889154016319
# -99.28774319800658
# -101.14902619542377
# -39.83104507933566
# 151.40571295901844
# 143.78885080051128
# -70.73344909108619
# -139.66829236568145
# 97.18490531098465
# -20.893748311097006
# -106.48746954421264
# -114.1043317027198
# -51.79615232284753
# 58.66563914072696
# 80.3579139523427
# -99.03872078582708
# -123.31446090285459
# -192.24930417744986
# 153.51601836861516
# 263.9778098321896
# -812.0156789905949
# -660.2801781752274
# 239.4555105261663
# -17.632873360566713
# 9.132037852073811
# -399.6918468500266
# 422.58999290577196
# 574.3254937211394
# 593.5438423265713
# 585.0538206239684
# 363.22036965247884
# 202.9948471345084
# 321.9611688885
# 64.87278500176701
# -558.5561712074618
# -567.0461929100647
# ...

# %%
#plt.figure()
#imgplot = plt.imshow(final_image_reduced)

plt.figure()
imgplot = plt.imshow(final_image)

plt.figure()
implot = plt.imshow(final_image_blown)

#print(final_image - final_image_reduced)

# %%
identities = [combination_of_permutations([1],[range(0,n)]) for n in range(1,10)]

#for rho in identities:
#    plt.figure()
#    img = plt.imshow(rho.genFuzzyMatrix(28)/factorial(28))
    
rho = identities[1]
for i in range(2,28):
    plt.figure()
    plt.imshow(rho.genFuzzyMatrix(i)/factorial(i))
# Out:
# /tmp/ipykernel_1477/3498709348.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
